# %% [markdown]
# # Python Programming
#
#
# - Data Types

# %%
type(1)
# Out:
# int

# %%
type("Hello")
# Out:
# str

# %%
type(True)
# Out:
# bool

# %%
type(1.0)
# Out:
# float

# %% [markdown]
# - Strings

# %%
"hello"
# Out:
# 'hello'

# %%
'hello'
# Out:
# 'hello'

# %%
type("Hello")
# Out:
# str

# %%
type('Hello')
# Out:
# str

# %% [markdown]
# # Variable Assignment

# %%
# var name = value

# %%
a = 10

# %%
type(a)
# Out:
# int

# %%
a = "SHN"

# %%
type(a)
# Out:
# str

# %%
## Mathematical Operation
a= 10
b = 20

# %%
print(a + b)
print(a*b)
print(b%a)
print((a*b)+(a/b))
# Out:
# 30
# 200
# 0
# 200.5

# %% [markdown]
# # Print

# %% [markdown]
# # Single variable

# %%
s = "SHN"
print(s)
# Out:
# SHN

# %% [markdown]
# # Multiple Variables

# %%
s = "Ram is"
age = 19
city = "Lonere"
print(s, age, city)
# Out:
# Ram is 19 Lonere

# %%
print('SHN')
# Out:
# SHN

# %%
first_name = 'Shreekant'
last_name = 'Nannaware'

# %%
print("My first name is {} and Last name is {}".format(first_name,last_name))
# Out:
# My first name is Shreekant and Last name is Nannaware

# %%
print("My first name is {} and Last name is {}".format(last_name,first_name))
# Out:
# My first name is Nannaware and Last name is Shreekant

# %%
print("My first name is {first} and Last name is {last}".format(first = first_name, last = last_name))
# Out:
# My first name is Shreekant and Last name is Nannaware

# %%
print("My first name is {first} and Last name is {last}".format(last = last_name, first = first_name))
# Out:
# My first name is Shreekant and Last name is Nannaware

# %% [markdown]
# #  Using sep and end parameter

# %% [markdown]
# ## end Parameter with '@'

# %%
print("Python", end='@')
print("programming")
# Out:
# Python@programming

# %%
print('Shree', 'dbatu.ac.in', sep='@')
# Out:
# Shree@dbatu.ac.in

# %% [markdown]
# ## Seprating with Comma

# %%
print('G', 'F', 'G', sep='')
# Out:
# GFG

# %% [markdown]
# ## for formatting a date

# %%
print('09', '02', '2025', sep='-')
# Out:
# 09-02-2025

# %% [markdown]
# ## Using f-string

# %%
name = 'Shreekant'
age = 19
print(f"Hello, My name is {name} and I'm {age} years old.")
# Out:
# Hello, My name is Shreekant and I'm 19 years old.

# %% [markdown]
# ## Using the % Operator
# We can use ‘%’ operator. % values are replaced with zero or more value of elements. The formatting using % is similar to that of ‘printf’ in the C programming language.
#
# %d –integer
# %f – float
# %s – string
# %x –hexadecimal
# %o – octal

# %%
# Taking input from the user
num = int(input("Enter a value: "))

add = num + 5

# Output
print("The sum is %d" %add)
# Out:
# Enter a value: 20
# The sum is 25

# %% [markdown]
# ## Take Multiple Input in Python
# We are taking multiple input from the user in a single line, splitting the values entered by the user into separate variables for each value using the split() method. Then, it prints the values with corresponding labels, either two or three, based on the number of inputs provided by the user.

# %%
# taking two inputs at a time
x, y = input("Enter two values: ").split()
print("Number of boys: ", x)
print("Number of girls: ", y)
# Out:
# Enter two values: 20 25
# Number of boys:  20
# Number of girls:  25

# %%
# taking three inputs at a time
x, y, z = input("Enter three values: ").split()
print("Total number of students: ", x)
print("Number of boys is : ", y)
print("Number of girls is : ", z)
# Out:
# Enter three values: 20 10 10
# Total number of students:  20
# Number of boys is :  10
# Number of girls is :  10

# %% [markdown]
# ## Take Conditional Input from user in Python

# %%
# Prompting the user for input
age_input = input("Enter your age: ")

# Converting the input to an integer
age = int(age_input)

# Checking conditions based on user input
if age < 0:
    print("Please enter a valid age.")
elif age < 18:
    print("You are a minor.")
elif age >= 18 and age < 65:
    print("You are an adult.")
else:
    print("You are a senior citizen.")
# Out:
# Enter your age: 19
# You are an adult.

# %% [markdown]
# ## Taking input in Python
# Python input() function is used to take user input. By default, it returns the user input in form of a string.

# %%
name = input("Enter your name: ")
print("Hello,", name, "! Welcome!")
# Out:
# Enter your name: Shreekant
# Hello, Shreekant ! Welcome!

# %% [markdown]
# ## How to Change the Type of Input in Python

# %%
# Taking input as string
color = input("What color is rose?: ")
print(color)
# Out:
# What color is rose?: red
# red

# %%
# Taking input as int
# Typecasting to int
n = int(input("How many roses?: "))
print(n)
# Out:
# How many roses?: 5
# 5

# %%
# Taking input as float
# Typecasting to float
price = float(input("Price of each rose?: "))
print(price)
# Out:
# Price of each rose?: 20.5
# 20.5

# %% [markdown]
# ## Find DataType of Input in Python

# %%
a = "Hello World"
b = 10
c = 11.22
d = ("Computers", "for", "students")
e = ["Computers", "for", "students"]
f = {"Computers": 1, "for":2, "students":3}


print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(e))
print(type(f))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'tuple'>
# <class 'list'>
# <class 'dict'>
